2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=5")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=6")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=7")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=8")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=9")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=10")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=11")
li.append("https://kineticrealestate.com/home-search/listings?search_type=place&place=San+Mateo&county=San+Mateo+County&state=California&south=37.510937&west=-122.3557821&north=37.6021349&east=-122.275478&omnibox=San+Mateo%2C+CA%2C+USA&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&property_type%5B%5D=Co-op&property_type%5B%5D=Condo&property_type%5B%5D=Commercial&property_type%5B%5D=Land&property_type%5B%5D=Multi-family&property_type%5B%5D=Manufactured&property_type%5B%5D=Residential&property_type%5B%5D=Townhouse&property_type%5B%5D=Other&status_days%5BActive%5D=36500&status_days%5BUnder+Contract%5D=36500&status_days%5BPending%5D=36500&status%5B%5D=Sold&status_days%5BSold%5D=365&mailer_schedule=instant&order=status_modified_at%3Adesc&page=12")


res = str()
for i in range(116):
    req = requests.get(li[i])
    soup = BeautifulSoup(req.content, "html.parser")
    res += str(soup.get_text())
 
print(res)

sys.stdout.close()
sys.stdout=stdoutOrigin

# %%
#Removing spaces , empty lines and replacing the special characters in the text data

import pandas as pd

import re
myfile=open("raw.txt")
txt=myfile.read()
text=txt.lower()
#print(text)

import re
with open("raw.txt",'r')as file , open('inpu','w')as f:
    for line in file:
        if(line.strip()):
            line = re.sub(' +',' ',line)
            line = line.replace("*","").replace(":","")
            f.write(line)

# %%
#cleaning the text data by removing unwanted data and converting the text into list format


with open('inpu', 'r') as input_file, open('outp.txt', 'w') as output_file:
    # read the lines of the input file
    lines = input_file.readlines()

    # loop through each line and check if it contains '$'
    for line in lines:
        if '$' in line:
            # write the line to the output file if it contains '$'
            output_file.write(line)

            
my_file = open("outp.txt", "r")
  
data = my_file.read()
data_into_list = data.replace('\n', ' ').split(".")

#print(data_into_list)
my_file.close()

list1=[]
for item in data_into_list:
    x = item.split("|")
    list1.append(x)
#print(list1)


list1=[]
try:

    with open('outp.txt', 'r') as fr:

        # reading line by line

        lines = fr.readlines()

         

        # pointer for position

        ptr = 1

     

        # opening in writing mode

        with open('outp', 'w') as fw:

            for line in lines:
                x = line.split("|")
                list1.append(x)
                ptr += 1

    print(list1)

     

except:

    print("Oops! something error")
# Out:
# [[' $1,088,0003 Beds', '2 Baths', '1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 94117Under Contract', 'MLS® ML81906832\n'], [' $565,0001 Bed', '1 Bath', '669 ft²8300 Oceanview TER 316, SAN FRANCISCO, CA 94132Pending', 'MLS® ML81918396\n'], [' $1,799,0003 Beds', '2 Baths', '1,822 ft²4027 23rd ST, SAN FRANCISCO, CA 94114Active', 'MLS® ML81919952\n'], [' $1,498,0002 Beds', '2 Baths', '1,240 ft²401 Harrison ST 11F, SAN FRANCISCO, CA 94105Active', 'MLS® ML81919900\n'], [' $989,0003 Beds', '3 Baths', '1,208 ft²197 Goethe ST, SAN FRANCISCO, CA 94112Active', 'MLS® ML81919803\n'], [' $568,0001 Bed', '1 Bath', '670 ft²3981 Alemany BLVD 203, SAN FRANCISCO, CA 94132Under Contract', 'MLS® ML81919241\n'], [' $1,599,9995 Beds', '3 Baths', '1,785 ft²1457 Hudson AVE, SAN FRANCISCO, CA 94124Active', 'MLS® ML81919730\n'], [' $998,8883 Beds', '1 Bath', '1,866 ft²132 Britton ST, SAN FRANCISCO, CA 94134Active', 'MLS® ML81919668\n'], [' $839,8882 Beds', '1 Bath', '1,000 ft²1130 Brussels ST, SAN FRANCISCO, 
# ...

# %%
#string operations in the list 


for item in list1:
    s1=item[0]
    s1 = s1[:-6] + ',' + s1[-6:]
    item[0]=s1
print(list1)
# Out:
# [[' $1,088,000,3 Beds', '2 Baths', '1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 94117Under Contract', 'MLS® ML81906832\n'], [' $565,00,01 Bed', '1 Bath', '669 ft²8300 Oceanview TER 316, SAN FRANCISCO, CA 94132Pending', 'MLS® ML81918396\n'], [' $1,799,000,3 Beds', '2 Baths', '1,822 ft²4027 23rd ST, SAN FRANCISCO, CA 94114Active', 'MLS® ML81919952\n'], [' $1,498,000,2 Beds', '2 Baths', '1,240 ft²401 Harrison ST 11F, SAN FRANCISCO, CA 94105Active', 'MLS® ML81919900\n'], [' $989,000,3 Beds', '3 Baths', '1,208 ft²197 Goethe ST, SAN FRANCISCO, CA 94112Active', 'MLS® ML81919803\n'], [' $568,00,01 Bed', '1 Bath', '670 ft²3981 Alemany BLVD 203, SAN FRANCISCO, CA 94132Under Contract', 'MLS® ML81919241\n'], [' $1,599,999,5 Beds', '3 Baths', '1,785 ft²1457 Hudson AVE, SAN FRANCISCO, CA 94124Active', 'MLS® ML81919730\n'], [' $998,888,3 Beds', '1 Bath', '1,866 ft²132 Britton ST, SAN FRANCISCO, CA 94134Active', 'MLS® ML81919668\n'], [' $839,888,2 Beds', '1 Bath', '1,000 ft²1130 Brussels ST, SAN FR
# ...

# %%
#combining the list data to form a  dataframe


import pandas as pd 
    
 
lst=list1
#print(list1)
    
df = pd.DataFrame(lst, columns =['price','bathrooms','sqft_&_address','MLS_Number'])
#df


data=df
data.dropna(inplace = True)
  
# new data frame with split value columns

# split column into multiple columns by delimiter 
x=data['price'].str.split(',',n=2, expand=True)
x
# Out:
#           0    1           2
# 0        $1  088  000,3 Beds
# 1      $565   00      01 Bed
# 2        $1  799  000,3 Beds
# 3        $1  498  000,2 Beds
# 4      $989  000      3 Beds
# ...     ...  ...         ...
# 3721   $750  000      2 Beds
# 3722     $1  600  000,3 Beds
# 3723   $910  000      2 Beds
# 3724     $2  900  000,3 Beds
# 3725   $658   00      01 Bed
#
# [3227 rows x 3 columns]

# %%
df2 = x.join(data)
df2
# Out:
#           0    1           2               price bathrooms  \
# 0        $1  088  000,3 Beds   $1,088,000,3 Beds   2 Baths
# 1      $565   00      01 Bed      $565,00,01 Bed    1 Bath
# 2        $1  799  000,3 Beds   $1,799,000,3 Beds   2 Baths
# 3        $1  498  000,2 Beds   $1,498,000,2 Beds   2 Baths
# 4      $989  000      3 Beds     $989,000,3 Beds   3 Baths
# ...     ...  ...         ...                 ...       ...
# 3721   $750  000      2 Beds     $750,000,2 Beds    1 Bath
# 3722     $1  600  000,3 Beds   $1,600,000,3 Beds   2 Baths
# 3723   $910  000      2 Beds     $910,000,2 Beds   2 Baths
# 3724     $2  900  000,3 Beds   $2,900,000,3 Beds   2 Baths
# 3725   $658   00      01 Bed      $658,00,01 Bed    1 Bath
#
#                                          sqft_&_address          MLS_Number
# 0     1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 9...   MLS® ML81906832\n
# 1     669 ft²8300 Oceanview TER 316, SAN FRANCISCO, ...   MLS® ML81918396\n
# ...

# %%
df2['price'] = df2[0].str.cat(df2[1])
df2
# Out:
#           0    1           2     price bathrooms  \
# 0        $1  088  000,3 Beds     $1088   2 Baths
# 1      $565   00      01 Bed    $56500    1 Bath
# 2        $1  799  000,3 Beds     $1799   2 Baths
# 3        $1  498  000,2 Beds     $1498   2 Baths
# 4      $989  000      3 Beds   $989000   3 Baths
# ...     ...  ...         ...       ...       ...
# 3721   $750  000      2 Beds   $750000    1 Bath
# 3722     $1  600  000,3 Beds     $1600   2 Baths
# 3723   $910  000      2 Beds   $910000   2 Baths
# 3724     $2  900  000,3 Beds     $2900   2 Baths
# 3725   $658   00      01 Bed    $65800    1 Bath
#
#                                          sqft_&_address          MLS_Number
# 0     1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 9...   MLS® ML81906832\n
# 1     669 ft²8300 Oceanview TER 316, SAN FRANCISCO, ...   MLS® ML81918396\n
# 2     1,822 ft²4027 23rd ST, SAN FRANCISCO, CA 94114...   MLS® ML81919952\n
# ...

# %%
y=df2['sqft_&_address'].str.split('²',expand=True)
y
# Out:
#              0                                                  1
# 0     1,271 ft  695 Frederick ST, SAN FRANCISCO, CA 94117Under...
# 1       669 ft  8300 Oceanview TER 316, SAN FRANCISCO, CA 9413...
# 2     1,822 ft        4027 23rd ST, SAN FRANCISCO, CA 94114Active
# 3     1,240 ft  401 Harrison ST 11F, SAN FRANCISCO, CA 94105Ac...
# 4     1,208 ft       197 Goethe ST, SAN FRANCISCO, CA 94112Active
# ...        ...                                                ...
# 3721    974 ft     817 N Humboldt ST 214, SAN MATEO, CA 94401Sold
# 3722  1,080 ft          1832 Hemlock AVE, SAN MATEO, CA 94401Sold
# 3723  1,024 ft  1919 Alameda De Las Pulgas 83, SAN MATEO, CA 9...
# 3724  2,124 ft          3716 Hillside CT, SAN MATEO, CA 94403Sold
# 3725    692 ft  1919 Alameda De Las Pulgas 85, SAN MATEO, CA 9...
#
# [3227 rows x 2 columns]

# %%
df2
# Out:
#           0    1           2     price bathrooms  \
# 0        $1  088  000,3 Beds     $1088   2 Baths
# 1      $565   00      01 Bed    $56500    1 Bath
# 2        $1  799  000,3 Beds     $1799   2 Baths
# 3        $1  498  000,2 Beds     $1498   2 Baths
# 4      $989  000      3 Beds   $989000   3 Baths
# ...     ...  ...         ...       ...       ...
# 3721   $750  000      2 Beds   $750000    1 Bath
# 3722     $1  600  000,3 Beds     $1600   2 Baths
# 3723   $910  000      2 Beds   $910000   2 Baths
# 3724     $2  900  000,3 Beds     $2900   2 Baths
# 3725   $658   00      01 Bed    $65800    1 Bath
#
#                                          sqft_&_address          MLS_Number
# 0     1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 9...   MLS® ML81906832\n
# 1     669 ft²8300 Oceanview TER 316, SAN FRANCISCO, ...   MLS® ML81918396\n
# 2     1,822 ft²4027 23rd ST, SAN FRANCISCO, CA 94114...   MLS® ML81919952\n
# ...

# %%
df2['sq_ft']=y[0]
df2['address']=y[1]

df2 = df2.rename(columns={2: 'bedrooms'})
#df2

df2 = df2.reset_index(drop=True)
df2
# Out:
#           0    1    bedrooms     price bathrooms  \
# 0        $1  088  000,3 Beds     $1088   2 Baths
# 1      $565   00      01 Bed    $56500    1 Bath
# 2        $1  799  000,3 Beds     $1799   2 Baths
# 3        $1  498  000,2 Beds     $1498   2 Baths
# 4      $989  000      3 Beds   $989000   3 Baths
# ...     ...  ...         ...       ...       ...
# 3222   $750  000      2 Beds   $750000    1 Bath
# 3223     $1  600  000,3 Beds     $1600   2 Baths
# 3224   $910  000      2 Beds   $910000   2 Baths
# 3225     $2  900  000,3 Beds     $2900   2 Baths
# 3226   $658   00      01 Bed    $65800    1 Bath
#
#                                          sqft_&_address          MLS_Number  \
# 0     1,271 ft²695 Frederick ST, SAN FRANCISCO, CA 9...   MLS® ML81906832\n
# 1     669 ft²8300 Oceanview TER 316, SAN FRANCISCO, ...   MLS® ML81918396\n
# 2     1,822 ft²4027 23rd ST, SAN FRANCISCO, CA 94114...   MLS® ML81919952\n
# ...

# %%
#

list1=[]   
for i in range(3247):
    if len(df2['bedrooms'][i]) > 8:
        list1.append(i)
    
print(list1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 3227 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       3 list1=[]
#       4 for i in range(3247):
# ----> 5     if len(df2['bedrooms'][i]) > 8:
#       6         list1.append(i)
#       8 print(list1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
# ...

# %%
df2 = df2.drop(list1)

# %%
df2=df2.drop(columns=[0,1,"sqft_&_address"])
df2

# %%
df2 = df2.reset_index(drop=True)
df2

# %%
data_csv = pd.DataFrame(df2)
data_csv
data_csv.to_csv("Project_Data.csv")

# %%
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

sns.regplot("price", "sq_ft");
